# %%
import csv
import dask.dataframe as dd
import pandas as pd
import numpy as np
import scipy as sc
from matplotlib import pyplot as plt
# %matplotlib inline
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn import svm
df1.data = pd.read_csv("",sep = ';',encoding = "ISO-8859-1")
df1.data.shape, df1.target.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-224a4836cb12> in <module>
#      10 from sklearn import svm
#      11 df1.data = pd.read_csv("info_pdo.csv",sep = ';',encoding = "ISO-8859-1")
# ---> 12 df1.data.shape, df1.target.shape
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'target'

# %%
print (np.shape(df1))

# %%
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-40-b27b76453ddb> in <module>
#       1 chunksize = 10 ** 8
# ----> 2 for chunk in pd.read_csv("info_pdo.csv", chunksize=chunksize):
#       3     process(chunk)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __next__(self)
#    1005     def __next__(self):
#    1006         try:
# -> 1007             return self.get_chunk()
#    1008         except StopIteration:
#    1009             self.close()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in get_chunk(self, size)
#    1068                 raise StopIteration
#    1069             size = min(size, self.nrows - self._currow)
# -> 1070         return self.read(nrows=size)
#    1071
#    1072
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1034                 raise ValueError('skipfooter not supported for iteration')
#    1035
# -> 1036         ret = self._engine.read(nrows)
#    1037
#    1038         # May alter columns / col_dict
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1846     def read(self, nrows=None):
#    1847         try:
# -> 1848             data = self._reader.read(nrows)
#    1849         except StopIteration:
#    1850             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 178, saw 2

# %%
df1.head
# Out:
# <bound method NDFrame.head of            Peri6  NUM_PERS_DESJ  NUM_PERS_DESJ_ENCO  ind_GPGR  interne  \
# 0         201701       23709869          4010001559         1      NaN
# 1         201702       23709869          4010001559         1      NaN
# 2         201703       23709869          4010001559         1      NaN
# 3         201704       23709869          4010001559         1      NaN
# 4         201705       23709869          4010001559         1      NaN
# 5         201706       23709869          4010001559         1      NaN
# 6         201707       23709869          4010001559         1      NaN
# 7         201708       23709869          4010001559         1      NaN
# 8         201709       23709869          4010001559         1      NaN
# 9         201710       23709869          4010001559         1      NaN
# 10        201711       23709869          4010001559         1      NaN
# 11        201712       23709869          4010001559         1      NaN
# 12        201801       23709869          4010001559         1      NaN
# 13        201802       23709869          4010001559         1      NaN
# 14        201803       23709869          4010001559         1      NaN
# 15        201804       23709869          4010001559         1      NaN
# 16        201805       23709869          4010001559         1      NaN
# 17        201512       17705879          4010030514         1      NaN
# 18        201601       17705879          4010030514         1      NaN
# 19        201602       17705879          4010030514         1      NaN
# 20        201603       17705879          4010030514         1      NaN
# 21        201604       17705879          4010030514         1      NaN
# 22        201605       17705879          4010030514         1      NaN
# 23        201606       17705879          4010030514         1      NaN
# 24        201607       17705879          4010030514         1      NaN
# 25        201608       17705879          4010030514         1      NaN
# 26        201609       17705879          4010030514         1      NaN
# 27        201610       17705879          4010030514         1      NaN
# 28        201611       17705879          4010030514         1      NaN
# 29        201612       17705879          4010030514         1      NaN
# ...          ...            ...                 ...       ...      ...
# 10477066  201512        5544386         94679999598         1      NaN
# 10477067  201601        5544386         94679999598         1      NaN
# 10477068  201602        5544386         94679999598         1      NaN
# 10477069  201603        5544386         94679999598         1      NaN
# 10477070  201604        5544386         94679999598         1      NaN
# 10477071  201605        5544386         94679999598         1      NaN
# 10477072  201606        5544386         94679999598         1      NaN
# 10477073  201607        5544386         94679999598         1      NaN
# 10477074  201608        5544386         94679999598         1      NaN
# 10477075  201609        5544386         94679999598         1      NaN
# 10477076  201610        5544386         94679999598         1      NaN
# 10477077  201611        5544386         94679999598         1      NaN
# 10477078  201612        5544386         94679999598         1      NaN
# 10477079  201701        5544386         94679999598         1      NaN
# 10477080  201702        5544386         94679999598         1      NaN
# 10477081  201703        5544386         94679999598         1      NaN
# 10477082  201704        5544386         94679999598         1      NaN
# 10477083  201705        5544386         94679999598         1      NaN
# 10477084  201706        5544386         94679999598         1      NaN
# 10477085  201707        5544386         94679999598         1      NaN
# 10477086  201708        5544386         94679999598         1      NaN
# 10477087  201709        5544386         94679999598         1      NaN
# 10477088  201710        5544386         94679999598         1      NaN
# 10477089  201711        5544386         94679999598         1      NaN
# 10477090  201712        5544386         94679999598         1      NaN
# 10477091  201801        5544386         94679999598         1      NaN
# 10477092  201802        5544386         94679999598         1      NaN
# 10477093  201803        5544386         94679999598         1      NaN
# 10477094  201804        5544386         94679999598         1      NaN
# 10477095  201805        5544386         94679999598         1      NaN
#
#          Groupe_Like  FAML_CPTE_OPER  FAML_CARTE_CRE  FAML_FINAN_CT  \
# 0                NaN             1.0             0.0            0.0
# 1                NaN             1.0             1.0            1.0
# 2                NaN             1.0             1.0            1.0
# 3                NaN             1.0             1.0            1.0
# 4                NaN             1.0             1.0            1.0
# 5                NaN             1.0             1.0            1.0
# 6                NaN             1.0             1.0            1.0
# 7                NaN             1.0             1.0            1.0
# 8                NaN             1.0             1.0            1.0
# 9                NaN             1.0             1.0            1.0
# 10               NaN             1.0             1.0            1.0
# 11               NaN             1.0             1.0            1.0
# 12               NaN             1.0             1.0            1.0
# 13               NaN             1.0             1.0            1.0
# 14               NaN             1.0             1.0            1.0
# 15               NaN             1.0             1.0            1.0
# 16               NaN             1.0             1.0            1.0
# 17               NaN             1.0             0.0            0.0
# 18               NaN             1.0             0.0            0.0
# 19               NaN             1.0             0.0            0.0
# 20               NaN             1.0             0.0            0.0
# 21               NaN             1.0             0.0            0.0
# 22               NaN             1.0             0.0            0.0
# 23               NaN             1.0             0.0            0.0
# 24               NaN             1.0             0.0            0.0
# 25               NaN             1.0             0.0            0.0
# 26               NaN             1.0             0.0            0.0
# 27               NaN             1.0             0.0            0.0
# 28               NaN             1.0             0.0            0.0
# 29               NaN             1.0             0.0            0.0
# ...              ...             ...             ...            ...
# 10477066         NaN             1.0             0.0            0.0
# 10477067         NaN             1.0             0.0            0.0
# 10477068         NaN             1.0             0.0            0.0
# 10477069         NaN             1.0             0.0            0.0
# 10477070         NaN             1.0             0.0            0.0
# 10477071         NaN             1.0             0.0            0.0
# 10477072         NaN             1.0             0.0            0.0
# 10477073         NaN             1.0             0.0            0.0
# 10477074         NaN             1.0             0.0            0.0
# 10477075         NaN             1.0             0.0            0.0
# 10477076         NaN             1.0             0.0            0.0
# 10477077         NaN             1.0             0.0            0.0
# 10477078         NaN             1.0             0.0            0.0
# 10477079         NaN             1.0             0.0            0.0
# 10477080         NaN             1.0             0.0            0.0
# 10477081         NaN             1.0             0.0            0.0
# 10477082         NaN             1.0             0.0            0.0
# 10477083         NaN             1.0             0.0            0.0
# 10477084         NaN             1.0             0.0            0.0
# 10477085         NaN             1.0             0.0            0.0
# 10477086         NaN             1.0             0.0            0.0
# 10477087         NaN             1.0             0.0            0.0
# 10477088         NaN             1.0             0.0            0.0
# 10477089         NaN             1.0             0.0            0.0
# 10477090         NaN             1.0             0.0            0.0
# 10477091         NaN             1.0             0.0            0.0
# 10477092         NaN             1.0             0.0            0.0
# 10477093         NaN             1.0             0.0            0.0
# 10477094         NaN             1.0             0.0            0.0
# 10477095         NaN             1.0             0.0            0.0
#
#           FAML_FINAN_LT      ...        NBR_EMPL_TOT_ICAN  PCT_PDO_APP  \
# 0                   0.0      ...                      NaN          NaN
# 1                   0.0      ...                      NaN          NaN
# 2                   0.0      ...                      NaN          NaN
# 3                   0.0      ...                      NaN          NaN
# 4                   0.0      ...                      NaN          NaN
# 5                   0.0      ...                      NaN          NaN
# 6                   0.0      ...                      NaN          NaN
# 7                   0.0      ...                      NaN          NaN
# 8                   0.0      ...                      NaN          NaN
# 9                   1.0      ...                      NaN          NaN
# 10                  1.0      ...                      NaN          NaN
# 11                  1.0      ...                      NaN          NaN
# 12                  1.0      ...                      NaN          NaN
# 13                  1.0      ...                      NaN          NaN
# 14                  1.0      ...                      NaN          NaN
# 15                  1.0      ...                      NaN          NaN
# 16                  1.0      ...                      NaN          NaN
# 17                  0.0      ...                      NaN          NaN
# 18                  0.0      ...                      NaN          NaN
# 19                  0.0      ...                      NaN          NaN
# 20                  0.0      ...                      NaN          NaN
# 21                  0.0      ...                      NaN          NaN
# 22                  0.0      ...                      NaN          NaN
# 23                  0.0      ...                      NaN          NaN
# 24                  0.0      ...                      NaN          NaN
# 25                  0.0      ...                      NaN          NaN
# 26                  0.0      ...                      NaN          NaN
# 27                  0.0      ...                      NaN          NaN
# 28                  0.0      ...                      NaN          NaN
# 29                  0.0      ...                      NaN          NaN
# ...                 ...      ...                      ...          ...
# 10477066            0.0      ...                      NaN          NaN
# 10477067            0.0      ...                      NaN          NaN
# 10477068            0.0      ...                      NaN          NaN
# 10477069            0.0      ...                      NaN          NaN
# 10477070            0.0      ...                      NaN          NaN
# 10477071            0.0      ...                      NaN          NaN
# 10477072            0.0      ...                      NaN          NaN
# 10477073            0.0      ...                      NaN          NaN
# 10477074            0.0      ...                      NaN          NaN
# 10477075            0.0      ...                      NaN          NaN
# 10477076            0.0      ...                      NaN          NaN
# 10477077            0.0      ...                      NaN          NaN
# 10477078            0.0      ...                      NaN          NaN
# 10477079            0.0      ...                      NaN          NaN
# 10477080            0.0      ...                      NaN          NaN
# 10477081            0.0      ...                      NaN          NaN
# 10477082            0.0      ...                      NaN          NaN
# 10477083            0.0      ...                      NaN          NaN
# 10477084            0.0      ...                      NaN          NaN
# 10477085            0.0      ...                      NaN          NaN
# 10477086            0.0      ...                      NaN          NaN
# 10477087            0.0      ...                      NaN          NaN
# 10477088            0.0      ...                      NaN          NaN
# 10477089            0.0      ...                      NaN          NaN
# 10477090            0.0      ...                      NaN          NaN
# 10477091            0.0      ...                      NaN          NaN
# 10477092            0.0      ...                      NaN          NaN
# 10477093            0.0      ...                      NaN          NaN
# 10477094            0.0      ...                      NaN          NaN
# 10477086      NaN         NaN           NaN      NaN            NaN      NaN
# 10477087      NaN         NaN           NaN      NaN            NaN      NaN
# 10477088      NaN         NaN           NaN      NaN            NaN      NaN
# 10477089      NaN         NaN           NaN      NaN            NaN      NaN
# 10477090      NaN         NaN           NaN      NaN            NaN      NaN
# 10477091      NaN         NaN           NaN      NaN            NaN      NaN
# 10477092      NaN         NaN           NaN      NaN            NaN      NaN
# 10477093      NaN         NaN           NaN      NaN            NaN      NaN
# 10477094      NaN         NaN           NaN      NaN            NaN      NaN
# 10477095      NaN         NaN           NaN      NaN            NaN      NaN
#
#           MNT_VENTE_LOC_AJUST  TAILLE_FINALE
# 0                         NaN            NaN
# 1                         NaN            NaN
# 2                         NaN             TP
# 3                         NaN             TP
# 4                         NaN             TP
# 5                         NaN             TP
# 6                         NaN             TP
# 7                         NaN             TP
# 8                         NaN             TP
# 9                         NaN             TP
# 10                        NaN             TP
# 11                        NaN             TP
# 12                        NaN             TP
# 13                        NaN             TP
# 14                        NaN             TP
# 15                        NaN             TP
# 16                        NaN             TP
# 17                        NaN            NaN
# 18                        NaN            NaN
# 19                        NaN            NaN
# 20                        NaN            NaN
# 21                        NaN            NaN
# 22                        NaN            NaN
# 23                        NaN             TP
# 24                        NaN             TP
# 25                        NaN             TP
# 26                        NaN             TP
# 27                        NaN             TP
# 28                        NaN             TP
# 29                        NaN             TP
# ...                       ...            ...
# 10477066                  NaN            NaN
# 10477067                  NaN            NaN
# 10477068                  NaN            NaN
# 10477069                  NaN            NaN
# 10477070                  NaN            NaN
# 10477071                  NaN            NaN
# 10477072                  NaN             TP
# 10477073                  NaN             TP
# 10477074                  NaN             TP
# 10477075                  NaN             TP
# 10477076                  NaN             TP
# 10477077                  NaN             TP
# 10477078                  NaN             TP
# 10477079                  NaN             TP
# 10477080                  NaN             TP
# 10477081                  NaN             TP
# 10477082                  NaN             TP
# 10477083                  NaN             TP
# 10477084                  NaN             TP
# 10477085                  NaN             TP
# 10477086                  NaN             TP
# 10477087                  NaN             TP
# 10477088                  NaN             TP
# 10477089                  NaN             TP
# 10477090                  NaN             TP
# 10477091                  NaN             TP
# 10477092                  NaN             TP
# 10477093                  NaN             TP
# 10477094                  NaN             TP
# 10477095                  NaN             TP
#
# [10477096 rows x 224 columns]>

# %%
pip install -U scikit-learn

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df1.data, df1.target, test_size=0.2, random_state=0)

X_train.shape, y_train.shape

X_test.shape, y_test.shape


clf = svm.SVC(kernel='linear', C=1).fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/sherbrookeinformatique/28oct.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell:/Users/sherbrookeinformatique/28oct.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> X_train, X_test, y_train, y_test = train_test_split(
#       <a href='vscode-notebook-cell:/Users/sherbrookeinformatique/28oct.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a>     df1.data, df1.target, test_size=0.2, random_state=0)
#       <a href='vscode-notebook-cell:/Users/sherbrookeinformatique/28oct.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a> X_train.shape, y_train.shape
#       <a href='vscode-notebook-cell:/Users/sherbrookeinformatique/28oct.ipynb#W5sZmlsZQ%3D%3D?line=5'>6</a> X_test.shape, y_test.shape
#
# NameError: name 'train_test_split' is not defined

# %%
df1.data.shape, df1.target.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/sherbrookeinformatique/28oct.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/Users/sherbrookeinformatique/28oct.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> df1.data.shape, df1.target.shape
#
# NameError: name 'df1' is not defined
