# %% [markdown]
# # Chapter 6 -  Data Sourcing via Web
# ## Segment 5 - Introduction to NLP

# %%
import nltk

# %%
text = "La Chine : vers une domination mondiale totale! Vision d’un observateur fasciné et inquiet"

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# <h3>Sentence Tokenizer</h3>

# %%
from nltk.tokenize import sent_tokenize
sent_tk = sent_tokenize(text)
print("Sentence tokenizing the text: \n")
print(sent_tk)
# Out:
# Sentence tokenizing the text:
#
# ['La Chine : vers une domination mondiale totale!', 'Vision d’un observateur fasciné et inquiet']

# %% [markdown]
# ### Word Tokenizer

# %%
from nltk.tokenize import word_tokenize
word_tk = word_tokenize(text)
print("Word tokenizing the text: \n")
print(word_tk)
# Out:
# Word tokenizing the text:
#
# ['La', 'Chine', ':', 'vers', 'une', 'domination', 'mondiale', 'totale', '!', 'Vision', 'd', '’', 'un', 'observateur', 'fasciné', 'et', 'inquiet']

# %% [markdown]
# ### Removing stop words

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import stopwords

sw = set(stopwords.words("english"))
print("Stop words in English language are: \n")
print(sw)
# Out:
# Stop words in English language are:
#
# {'i', 'more', 'on', 'there', 'most', 'your', 'll', 'hasn', 'into', 'no', 'shouldn', "that'll", 'doing', 'other', 'he', 'been', 'yourselves', 'through', 'd', 'having', "you're", 'such', 'our', 'and', 'won', 'both', 'you', "hasn't", 'some', 'those', 'under', 'same', "you'd", 'just', "mustn't", 'here', 'then', "wouldn't", 'these', 'don', 'their', "don't", 'very', 'of', 'by', "should've", 're', 's', 'didn', 'yours', "you'll", 'only', 'him', 'because', 'wouldn', 'down', 'each', 'to', "hadn't", 'his', 'why', 'needn', 'below', 'weren', 'doesn', 'once', 'when', 'than', "weren't", 'couldn', 'about', 'itself', 'mustn', 'shan', 'its', 'did', 'before', "won't", 'own', "mightn't", "wasn't", 'which', 'ain', 't', "haven't", 'how', 'theirs', 'hers', 'them', 'or', 'are', 'am', 'until', 'the', 'between', 'few', 'should', 'what', "aren't", "you've", 'will', 'ourselves', 'too', 'where', 'not', 'this', 'yourself', 'y', "shouldn't", 'herself', 'wasn', 'if', 'while', 'now', 'we', 'himself', 'during', 'has', 'in', 'my', 'any', 'me', 'out', 'being', 'ours', 'over', "needn't", 'ma', 'does', 'they', 'themselves', 'nor', 'o', 'isn', 'who', 'be', 'off', 'have', "didn't", 'm', 'mightn', 'do', 'she', 'with', 'aren', 'above', 'after', 'from', 'can', 'up', 'again', "shan't", 'hadn', "it's", 'whom', 'further', 'it', 'at', 'myself', 'were', 'haven', 'was', 'against', "doesn't", 'so', 'an', 'had', 'is', 'for', 'all', 'her', 'that', 'as', "couldn't", 'but', 've', "she's", 'a', "isn't"}

# %%
filtered_words = [w for w in word_tk if not w in sw]

print("The text after removing stop words \n")
print(filtered_words)
# Out:
# The text after removing stop words
#
# ['La', 'Chine', ':', 'vers', 'une', 'domination', 'mondiale', 'totale', '!', 'Vision', '’', 'un', 'observateur', 'fasciné', 'et', 'inquiet']

# %% [markdown]
# <h3>Stemming</h3>

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

port_stem = PorterStemmer()

# %%
stemmed_words = []

for w in filtered_words:
    stemmed_words.append(port_stem.stem(w))
    
print("Filtered Sentence: \n", filtered_words, "\n")
print("Stemmed Sentence: \n", stemmed_words)
# Out:
# Filtered Sentence:
#  ['La', 'Chine', ':', 'vers', 'une', 'domination', 'mondiale', 'totale', '!', 'Vision', '’', 'un', 'observateur', 'fasciné', 'et', 'inquiet']
#
# Stemmed Sentence:
#  ['La', 'chine', ':', 'ver', 'une', 'domin', 'mondial', 'total', '!', 'vision', '’', 'un', 'observateur', 'fasciné', 'et', 'inquiet']

# %% [markdown]
# # Lemmatizing

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
from nltk.stem.wordnet import WordNetLemmatizer

lem = WordNetLemmatizer()

from nltk.stem.porter import PorterStemmer
stem = PorterStemmer()

lemm_words = []

for i in range(len(filtered_words)):
    lemm_words.append(lem.lemmatize(filtered_words[i]))
    
print(lemm_words)
# Out:
# ['La', 'Chine', ':', 'vers', 'une', 'domination', 'mondiale', 'totale', '!', 'Vision', '’', 'un', 'observateur', 'fasciné', 'et', 'inquiet']

# %% [markdown]
# <h3>Parts of Speech Tagging</h3>

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
from nltk import pos_tag
pos_tagged_words = pos_tag(word_tk)

print(pos_tagged_words)
# Out:
# [('La', 'NNP'), ('Chine', 'NNP'), (':', ':'), ('vers', 'NNS'), ('une', 'VBP'), ('domination', 'NN'), ('mondiale', 'JJ'), ('totale', 'NN'), ('!', '.'), ('Vision', 'NNP'), ('d', 'VBZ'), ('’', 'NNP'), ('un', 'JJ'), ('observateur', 'NN'), ('fasciné', 'NN'), ('et', 'VBP'), ('inquiet', 'JJ')]

# %% [markdown]
# <h3>Frequency Distribution Plots</h3>

# %%
from nltk.probability import FreqDist
fd = FreqDist(word_tk)
print(fd)
# Out:
# <FreqDist with 17 samples and 17 outcomes>

# %%
import matplotlib.pyplot as plt
fd.plot(30, cumulative=False)
plt.show()

# %%
fd_alpha = FreqDist(text)
print(fd_alpha)
fd_alpha.plot(30, cumulative=False)
# Out:
# <FreqDist with 26 samples and 90 outcomes>
