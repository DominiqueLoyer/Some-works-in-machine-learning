# %%
# Chapter 6 -  Data Sourcing via Web
## Segment 5 - Introduction to NLP

# %%
import nltk

# %%
text = "On Wednesday, the Association for Computing Machinery, the world’s largest society of computing professionals, announced that Hinton, LeCun and Bengio had won this year’s Turing Award for their work on neural networks. The Turing Award, which was introduced in 1966, is often called the Nobel Prize of computing, and it includes a $1 million prize, which the three scientists will share."

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# <h3>Sentence Tokenizer</h3>

# %%
from nltk.tokenize import sent_tokenize
sent_tk = sent_tokenize(text)
print("Sentence tokenizing the text: \n")
print(sent_tk)
# Out:
# Sentence tokenizing the text:
#
# ['On Wednesday, the Association for Computing Machinery, the world’s largest society of computing professionals, announced that Hinton, LeCun and Bengio had won this year’s Turing Award for their work on neural networks.', 'The Turing Award, which was introduced in 1966, is often called the Nobel Prize of computing, and it includes a $1 million prize, which the three scientists will share.']

# %% [markdown]
# ### Word Tokenizer

# %%
from nltk.tokenize import word_tokenize
word_tk = word_tokenize(text)
print("Word tokenizing the text: \n")
print(word_tk)
# Out:
# Word tokenizing the text:
#
# ['On', 'Wednesday', ',', 'the', 'Association', 'for', 'Computing', 'Machinery', ',', 'the', 'world', '’', 's', 'largest', 'society', 'of', 'computing', 'professionals', ',', 'announced', 'that', 'Hinton', ',', 'LeCun', 'and', 'Bengio', 'had', 'won', 'this', 'year', '’', 's', 'Turing', 'Award', 'for', 'their', 'work', 'on', 'neural', 'networks', '.', 'The', 'Turing', 'Award', ',', 'which', 'was', 'introduced', 'in', '1966', ',', 'is', 'often', 'called', 'the', 'Nobel', 'Prize', 'of', 'computing', ',', 'and', 'it', 'includes', 'a', '$', '1', 'million', 'prize', ',', 'which', 'the', 'three', 'scientists', 'will', 'share', '.']

# %% [markdown]
# ### Removing stop words

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import stopwords

sw = set(stopwords.words("english"))
print("Stop words in English language are: \n")
print(sw)
# Out:
# Stop words in English language are:
#
# {'nor', 'such', 'all', 'because', "needn't", 'into', 'are', 't', 'ma', 'once', 'has', 'if', "haven't", 'herself', "you've", 'who', 'will', 'so', 'having', "don't", 'yourselves', 'these', 'above', "didn't", 'his', 'it', 'what', 'from', 'don', "mightn't", 'can', 'we', "it's", 'himself', 'no', 'wouldn', 'where', 'yours', 'between', 'been', 'as', 'this', 'hers', 'which', 'below', 'same', 'while', 'both', 'couldn', 'm', 'most', 'some', 're', 'yourself', 'in', 'does', "wouldn't", 've', 'of', 'you', 'an', "doesn't", 'why', 'mustn', 'was', 'and', 'about', 'than', 'should', 'up', 'did', 'she', 'ours', 'when', 'her', 'doesn', "you'd", 'for', 'again', 'not', "wasn't", 'weren', 'there', 'on', 'have', 'doing', "you'll", 'or', 'how', 'didn', 'o', "she's", 'their', 'me', 'aren', 'more', "couldn't", 'mightn', 'off', 'i', "shouldn't", 'hasn', 'wasn', "mustn't", 'down', "aren't", 'own', 'now', 'theirs', 'won', 'be', "isn't", 'whom', 'just', 'them', "you're", 'is', 'very', "shan't", 'needn', 's', 'hadn', "should've", 'only', 'they', "weren't", 'haven', 'with', 'too', 'other', "hasn't", 'am', 'until', 'my', 'against', 'through', "that'll", 'our', 'under', 'him', 'that', 'at', 'themselves', 'those', 'd', 'a', 'to', 'had', 'before', 'were', 'each', 'few', 'the', 'ain', 'shouldn', 'over', 'he', 'then', 'out', "hadn't", 'but', 'y', 'your', 'll', 'its', 'ourselves', "won't", 'do', 'by', 'shan', 'myself', 'being', 'any', 'itself', 'after', 'during', 'further', 'here', 'isn'}

# %%
filtered_words = [w for w in word_tk if not w in sw]

print("The text after removing stop words \n")
print(filtered_words)
# Out:
# The text after removing stop words
#
# ['On', 'Wednesday', ',', 'Association', 'Computing', 'Machinery', ',', 'world', '’', 'largest', 'society', 'computing', 'professionals', ',', 'announced', 'Hinton', ',', 'LeCun', 'Bengio', 'year', '’', 'Turing', 'Award', 'work', 'neural', 'networks', '.', 'The', 'Turing', 'Award', ',', 'introduced', '1966', ',', 'often', 'called', 'Nobel', 'Prize', 'computing', ',', 'includes', '$', '1', 'million', 'prize', ',', 'three', 'scientists', 'share', '.']

# %% [markdown]
# <h3>Stemming</h3>

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

port_stem = PorterStemmer()

# %%
stemmed_words = []

for w in filtered_words:
    stemmed_words.append(port_stem.stem(w))
    
print("Filtered Sentence: \n", filtered_words, "\n")
print("Stemmed Sentence: \n", stemmed_words)
# Out:
# Filtered Sentence:
#  ['On', 'Wednesday', ',', 'Association', 'Computing', 'Machinery', ',', 'world', '’', 'largest', 'society', 'computing', 'professionals', ',', 'announced', 'Hinton', ',', 'LeCun', 'Bengio', 'year', '’', 'Turing', 'Award', 'work', 'neural', 'networks', '.', 'The', 'Turing', 'Award', ',', 'introduced', '1966', ',', 'often', 'called', 'Nobel', 'Prize', 'computing', ',', 'includes', '$', '1', 'million', 'prize', ',', 'three', 'scientists', 'share', '.']
#
# Stemmed Sentence:
#  ['On', 'wednesday', ',', 'associ', 'comput', 'machineri', ',', 'world', '’', 'largest', 'societi', 'comput', 'profession', ',', 'announc', 'hinton', ',', 'lecun', 'bengio', 'year', '’', 'ture', 'award', 'work', 'neural', 'network', '.', 'the', 'ture', 'award', ',', 'introduc', '1966', ',', 'often', 'call', 'nobel', 'prize', 'comput', ',', 'includ', '$', '1', 'million', 'prize', ',', 'three', 'scientist', 'share', '.']

# %% [markdown]
# # Lemmatizing

# %% [markdown]
# <h3>Parts of Speech Tagging</h3>

# %% [markdown]
# <h3>Frequency Distribution Plots</h3>
